# %%
import pandas as pd
data= pd.read_excel("pgcb+hourly+generation+dataset+(bangladesh)\PGCB_date_power_demand.xlsx")
data.head()
# Out:
#              datetime  generation_mw  demand_mw  load_shedding   gas  \
# 0 2015-04-19 22:00:00         6323.0       6323              0     0
# 1 2015-04-19 21:00:00         6667.0       6667              0     0
# 2 2015-04-19 19:00:00         6897.0       6897              0  4415
# 3 2015-04-19 18:30:00         6933.0       6933              0  4423
# 4 2015-04-19 18:00:00         6874.0       6874              0  4319
#
#    liquid_fuel  coal  hydro  solar  wind  india_bheramara_hvdc  india_tripura  \
# 0            0     0      0    NaN   NaN                     0              0
# 1            0     0      0    NaN   NaN                     0              0
# 2         1836   161     41    NaN   NaN                   444              0
# 3         1862   159     45    NaN   NaN                   444              0
# 4         1892   155     65    NaN   NaN                   443              0
#
#    india_adani  nepal       remarks
# 0          NaN    NaN           NaN
# ...

# %%
data.iloc[len(data)-1]
# Out:
# datetime                2025-06-17 00:00:00
# generation_mw                       14628.0
# demand_mw                             14650
# load_shedding                            21
# gas                                    6302
# liquid_fuel                            1672
# coal                                   4186
# hydro                                   172
# solar                                   0.0
# wind                                   41.0
# india_bheramara_hvdc                    924
# india_tripura                            42
# india_adani                          1251.0
# nepal                                  38.0
# remarks                                 NaN
# Name: 92649, dtype: object

# %%
data2 = pd.read_csv("POWER_Point_Hourly_20150101_20260211_023d71N_090d42E_LST (1).csv",header=11)
data2.head()
