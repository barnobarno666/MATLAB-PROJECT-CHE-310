# %%
import pandas as pd
data = pd.read_csv('FINAL_V7.csv')
data.head()
# Out:
#    Unnamed: 0  day  month  year        Date      Time  Generation(MW)  \
# 0           0   19      4  2015  2015-04-19  00:00:00          4821.0
# 1           1   19      4  2015  2015-04-19  01:00:00          3612.0
# 2           2   19      4  2015  2015-04-19  02:00:00          3727.0
# 3           3   19      4  2015  2015-04-19  03:00:00          3632.0
# 4           4   19      4  2015  2015-04-19  04:00:00          3641.0
#
#    Demand(MW)  Loadshed  Gas  ...    r3h_avg        rfq        r1q        r3q  \
# 0        4821         0    0  ...  139.18788  42.804626  113.00199  104.82534
# 1        3612         0    0  ...  139.18788  42.804626  113.00199  104.82534
# 2        3727         0    0  ...  139.18788  42.804626  113.00199  104.82534
# 3        3632         0    0  ...  139.18788  42.804626  113.00199  104.82534
# 4        3641         0    0  ...  139.18788  42.804626  113.00199  104.82534
#
#    version  gdp_nominal_billions_usd  gdp_ppp_billions_intl_dollar  \
# ...

# %%
data['Date'].iloc[0]
# Out:
# '2015-04-19'

# %%
import pandas as pd

# 1. Ensure the 'Date' column is in datetime format
# (If it's already datetime, you can skip this line)
data['Date'] = pd.to_datetime(data['Date'])

# 2. Create the 'Weekday' column with the full name
data['Weekday'] = data['Date'].dt.day_name()

# Optional: If you want abbreviations (Mon, Tue) instead:
# data['Weekday'] = data['Date'].dt.strftime('%a')

print(data.head())
# Out:
#    Unnamed: 0  day  month  year       Date      Time  Generation(MW)  \
# 0           0   19      4  2015 2015-04-19  00:00:00          4821.0
# 1           1   19      4  2015 2015-04-19  01:00:00          3612.0
# 2           2   19      4  2015 2015-04-19  02:00:00          3727.0
# 3           3   19      4  2015 2015-04-19  03:00:00          3632.0
# 4           4   19      4  2015 2015-04-19  04:00:00          3641.0
#
#    Demand(MW)  Loadshed  Gas  ...        rfq        r1q        r3q  version  \
# 0        4821         0    0  ...  42.804626  113.00199  104.82534    final
# 1        3612         0    0  ...  42.804626  113.00199  104.82534    final
# 2        3727         0    0  ...  42.804626  113.00199  104.82534    final
# 3        3632         0    0  ...  42.804626  113.00199  104.82534    final
# 4        3641         0    0  ...  42.804626  113.00199  104.82534    final
#
#    gdp_nominal_billions_usd  gdp_ppp_billions_intl_dollar  gni_billions_usd  \
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  day  month  year       Date      Time  Generation(MW)  \
# 0           0   19      4  2015 2015-04-19  00:00:00          4821.0
# 1           1   19      4  2015 2015-04-19  01:00:00          3612.0
# 2           2   19      4  2015 2015-04-19  02:00:00          3727.0
# 3           3   19      4  2015 2015-04-19  03:00:00          3632.0
# 4           4   19      4  2015 2015-04-19  04:00:00          3641.0
#
#    Demand(MW)  Loadshed  Gas  ...        rfq        r1q        r3q  version  \
# 0        4821         0    0  ...  42.804626  113.00199  104.82534    final
# 1        3612         0    0  ...  42.804626  113.00199  104.82534    final
# 2        3727         0    0  ...  42.804626  113.00199  104.82534    final
# 3        3632         0    0  ...  42.804626  113.00199  104.82534    final
# 4        3641         0    0  ...  42.804626  113.00199  104.82534    final
#
#    gdp_nominal_billions_usd  gdp_ppp_billions_intl_dollar  gni_billions_usd  \
# ...

# %%
data.to_csv('FINAL_V8.csv', index=False)
