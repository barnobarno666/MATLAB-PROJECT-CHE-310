# %%
import pandas as pd 
main_data= pd.read_csv("MERGED FINAL.csv")
main_data.head()
# Out:
#               main_name  BY  CD + BY  CD  SW_%  KW_%  LF_%  ST_%      Time  \
# 0  BY + 40% SW + 60% KW   1        0   0  40.0  60.0   0.0   0.0  0.000000
# 1  BY + 40% SW + 60% KW   1        0   0  40.0  60.0   0.0   0.0  0.198553
# 2  BY + 40% SW + 60% KW   1        0   0  40.0  60.0   0.0   0.0  0.201217
# 3  BY + 40% SW + 60% KW   1        0   0  40.0  60.0   0.0   0.0  0.203875
# 4  BY + 40% SW + 60% KW   1        0   0  40.0  60.0   0.0   0.0  0.206527
#
#       Volume
# 0   0.000000
# 1  38.298758
# 2  38.444227
# 3  38.589697
# 4  38.735166

# %%
Volume = main_data['Volume']
