# %%
import os 
pdf_folder="PDF"
pdf_files=os.listdir(f"{pdf_folder}")
pdf_files=sorted(pdf_files)
pdf_paths=[os.path.join(pdf_folder , pdf) for pdf in pdf_files]
pdf_paths
# Out:
# ['PDF\\20230304_dengue_all.pdf', 'PDF\\20250220_dengue_all.pdf']

# %%
prompt = """ From the pdf files, make me a dataset that would have, columns:date ,  division , district, ,number of cases in that district. the information is given in a bangla table in the pdf. mainly from this table (স্বাস্থ্য অধিদপ্তরের হেলথ ইমার্জেন্সি অপারেশন সেন্টার ও কন্ট্রোল রুম ঢাকা থেকে প্রেরিত ডেঙ্গু রোগে আক্রান্ত, চিকিৎসাপ্রাপ্ত ও মৃত্যুর প্রতিবেদন।)
Output the table in json. Stricly output just the table json and nothing else
    """
API_KEY ="XXXXNX"
